# %%
from llama_cpp import Llama

# %%
llm = Llama(
    # model_path='models/mistral_textfx/mistral_similes-Q5_K_S.gguf',
    model_path='../models/mistral_similes-Q5_K_S.gguf',
    chat_format="mistral-instruct",
    logits_all=True
)
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 291 tensors from ../models/mistral_similes-Q5_K_S.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = .
# llama_model_loader: - kv   2:                       llama.context_length u32              = 32768
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# ...

# %%
completion_result = llm.create_completion(
    'Create ONE simile that illustrates this concept: sleep',
    max_tokens=512, temperature=0.5,
    logprobs=10
)

print(completion_result['choices'][0]['logprobs'])
print(completion_result['choices'][0]['logprobs'])
print(completion_result['choices'][0]['logprobs']['top_logprobs'])
# Out:
# llama_print_timings:        load time =    8810.28 ms
# llama_print_timings:      sample time =       4.49 ms /    46 runs   (    0.10 ms per token, 10244.99 tokens per second)
# llama_print_timings: prompt eval time =    8810.19 ms /    12 tokens (  734.18 ms per token,     1.36 tokens per second)
# llama_print_timings:        eval time =    4205.09 ms /    45 runs   (   93.45 ms per token,    10.70 tokens per second)
# llama_print_timings:       total time =   13099.67 ms /    57 tokens
# ...
